# %%
def displaybill():
    print("NAME","QTY","PRICE","TOTAL","DAYS")
    print(getDosaname(),getDosacount(),getDosaprice(),getDosacount()*getDosaprice(),
          getIdliname(),getIdlicount(),getIdliprice(), getIdlicount()*getIdliprice())
    
    
def getdiscount():
    dis=getbill()/100*20
def discount():
    days=int(input())
    if(day==1):
        discount(displaybill)
        
        
def days():
    print("1 monday")
    print("2 thursday")
    print("3 sunday")
        
bill=0
def setbill(price,qty):
    global bill
    bill=bill+price*qty
def getbill():
    return bill
def setdisount():
    return discount
Dosacount=0
def setDosacount(plates):
    global Dosacount
    Dosacount=Dosacount+plates
Idlicount=0
def setIdlicount(plates):
    global Idlicount
    Idlicount=Idlicount+plates
def getDosacount():
    return Dosacount
def getIdlicount():
    return Idlicount
def getDosaname():
    return "Dosa"
def getIdliname():
    return "Idli"
def getDosaprice():
    return 100
def getIdliprice():
    return 60


def menu():
    print("1",getDosaname())
    print("price",getDosaprice())
    print("2",getIdliname())
    print("price",getIdliprice())
    
    
    
def manager():
    print("WELCOME TO HOTEL")
    flag=True
    while(flag):
        
        menu()
        opt=int(input())
        if(opt==1):
            qty=int(input("enter qty"))
            setbill(getDosaprice(),qty)
            setDosacount(qty)
            displaybill()
        if(opt==2):
            qty=int(input("enter qty"))
            setbill(getIdliprice(),qty)
            setIdlicount(qty)
            displaybill()
            flag=False
manager()
# Out:
# WELCOME TO HOTEL
# 1 Dosa
# price 100
# 2 Idli
# price 60
# 2
# enter qty2
# NAME QTY PRICE TOTAL DAYS
# Dosa 0 100 0 Idli 2 60 120
